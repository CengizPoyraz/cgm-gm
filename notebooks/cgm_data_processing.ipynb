# %%
import pandas as pd

# %%
df = pd.read_csv('/home/developer/Desktop/NOTEBOOK/GMS/cgm-gm/data/training_data_E_filtered_stations.csv')

# %%
df.head()
# Out:
#                    eid  src_lat  src_lon  sta_lat  sta_lon  depth  mag  \
# 0  20230206012651_CEYT  37.2650  36.8442  37.0105  35.7478    8.9  5.6
# 1  20230206012816_CEYT  37.2337  36.7805  37.0105  35.7478    5.0  6.6
# 2  20230206013509_CEYT  36.5780  35.6228  37.0105  35.7478    8.0  3.5
# 3  20230206013631_CEYT  37.0485  36.4047  37.0105  35.7478    8.2  5.6
# 4  20230206015118_CEYT  36.7788  36.7810  37.0105  35.7478    4.2  4.6
#
#    Sampling Frequency  Number of Time Steps  Delta t  ...           5991  \
# 0                 100                  6000      0.0  ... -163005.745045
# 1                 100                  6000      0.0  ... -563179.639870
# 2                 100                  6000      0.0  ...  -32714.224257
# 3                 100                  6000      0.0  ...    3223.094761
# 4                 100                  6000      0.0  ...   18364.187577
#
#             5992           5993           5994           5995           5996  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Columns: 6015 entries, eid to 6000
# dtypes: float64(6010), int64(4), object(1)
# memory usage: 25.8+ MB

# %%
df.describe()
# Out:
#           src_lat     src_lon     sta_lat     sta_lon       depth         mag  \
# count  562.000000  562.000000  562.000000  562.000000  562.000000  562.000000
# mean    37.604237   36.813596   37.413184   36.214694    8.322598    3.328114
# std      0.485715    0.428809    0.192728    0.527394    5.435144    0.687857
# min     36.126500   35.198000   36.375500   35.747800    1.000000    1.500000
# 25%     37.271675   36.530900   37.479500   35.826400    5.000000    2.900000
# 50%     37.656100   36.776900   37.479500   35.826400    6.000000    3.200000
# 75%     38.052850   37.043050   37.508700   36.900000    9.700000    3.700000
# max     38.424800   38.082700   37.508700   36.900000   28.800000    6.600000
#
#        Sampling Frequency  Number of Time Steps  Delta t  Min Frequency  ...  \
# count               562.0                 562.0    562.0          562.0  ...
# mean                100.0                6000.0      0.0            2.0  ...
# ...

# %%
df.columns[0:14]
# Out:
# Index(['eid', 'src_lat', 'src_lon', 'sta_lat', 'sta_lon', 'depth', 'mag',
#        'Sampling Frequency', 'Number of Time Steps', 'Delta t',
#        'Min Frequency', 'Max Frequency', 'Number of Frequency Steps', 'rup'],
#       dtype='object')
