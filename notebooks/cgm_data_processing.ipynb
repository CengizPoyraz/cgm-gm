# %%
import pandas as pd

# %%
df = pd.read_csv('/home/developer/Desktop/NOTEBOOK/GMS/cgm-gm/data/raw/training_data_E_component.csv')

# %%
df.head()
# Out:
#                    eid  src_lat  src_lon  sta_lat  sta_lon  depth  mag  \
# 0  20230206001600_KARS  41.1977  44.0507  40.6152  43.0937    4.3  3.3
# 1  20230206012651_CEYT  37.2650  36.8442  37.0105  35.7478    8.9  5.6
# 2  20230206012816_CEYT  37.2337  36.7805  37.0105  35.7478    5.0  6.6
# 3  20230206013509_CEYT  36.5780  35.6228  37.0105  35.7478    8.0  3.5
# 4  20230206013631_CEYT  37.0485  36.4047  37.0105  35.7478    8.2  5.6
#
#    Sampling Frequency  Number of Time Steps  Delta t  ...           5991  \
# 0                 100                  6000      0.0  ...     146.357215
# 1                 100                  6000      0.0  ... -163005.745045
# 2                 100                  6000      0.0  ... -563179.639870
# 3                 100                  6000      0.0  ...  -32714.224257
# 4                 100                  6000      0.0  ...    3223.094761
#
#             5992           5993           5994           5995           5996  \
# ...
